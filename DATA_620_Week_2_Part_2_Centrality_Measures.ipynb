# %% [markdown]
# <a href="https://colab.research.google.com/github/pujaroy280/DATA620WebAnalytics/blob/main/DATA_620_Week_2_Part_2_Centrality_Measures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Centrality measures can be used to predict (positive or negative) outcomes for a node.
#
# Your task in this week’s assignment is to identify an interesting set of network data that is available on the web (either through web scraping or web APIs) that could be used for analyzing and comparing centrality measures across nodes.  As an additional constraint, there should be at least one categorical variable available for each node (such as “Male” or “Female”; “Republican”, “Democrat,” or “Undecided”, etc.)
#
# In addition to identifying your data source, you should create a high level plan that describes how you would load the data for analysis, and describe a hypothetical outcome that could be predicted from comparing degree centrality across categorical groups.
#
# For this week’s assignment, you are not required to actually load or analyze the data.

# %% [markdown]
# ### **Group** (The DataDriven Team): Susanna Wong, Puja Roy, Mikhail Broomes & Marjete Vucinaj & Danny
#
#
# ### **Video** : https://youtu.be/uOTWlX2i-hU

# %% [markdown]
# # **Plan**
#
# ---

# %% [markdown]
# **Step 1**:
#
# *   Load dataset by uploading it csv to github and use pandas function to load the data
#   * we selected [NYPD arrests dataset](https://data.cityofnewyork.us/Public-Safety/NYPD-Arrest-Data-Year-to-Date-/uip8-fykc/about_data) from NYC Open Data portal
#
#
# *  Data Preparation and cleaning
#   * load python libraries
#   * check for missing data
#   * drop variables not needed for project

# %% [markdown]
# **Step 2:**
# Identify variables:
#
# *   variable to use as nodes: community district (CD)
#
# *   variable to use as edges, and is categorical: crimes committed ie OFNS_DESC

# %% [markdown]
# **Step 3**: Create visualization of Network Analysis for Crime vs Community District
# * use networkx to create a empty graph
# * group offense descriptions by community district into lists
# * add nodes and edges to graph, as specified in step 2

# %% [markdown]
# **Step 4**: Calculate Centrality Measures
#
# *  degree centrality
# *  eigenvector centrality
# * create a dataframe with both measures and generate summary statistics of it
# * filter top 5 Degree Centrality Eigenvector Centrality

# %% [markdown]
# **Step 5**: Compare the centrality measures of the categorical variable and draw conclusions

# %% [markdown]
# **Hypothetical outcome** that could be predicted from comparing degree of centrality across groups would help identify which groups are more connected or have  interactions between them. When considering the relationships and patterns between different types of crimes across community districts, its likely that certain CDs might have more connections to certain crime type. By using degree centrality which focuses on the number of direct connections, and eigenvector centrality which considers the quality of connections, this analysis can potentially show how crime types are distributed across community districts and further indicate additional resources and support in those areas.
